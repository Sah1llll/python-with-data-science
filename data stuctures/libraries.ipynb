# %%
import math

# %%
print(math.sqrt(20))
print(math.factorial(8))
print(math.pi)
print(math.log(10))
print(math.gcd(10, 20))
print(math.sin(90))
# Out:
# 4.47213595499958
# 40320
# 3.141592653589793
# 2.302585092994046
# 10
# 0.8939966636005579

# %%
from random import random, randint, choice, shuffle

# %%
print('get a random number between 0 and 1:', random())
print('get a random number between 1 and 100:', randint(20,30))
print('get a random number from a list:', choice([1,2,3,4,5,6,7]))
names = ['john', 'jane', 'jack', 'jill']
shuffle(names)
print('shuffle a list:', names)
# Out:
# get a random number between 0 and 1: 0.8221698555400765
# get a random number between 1 and 100: 22
# get a random number from a list: 6
# shuffle a list: ['jill', 'jack', 'jane', 'john']

# %%
from datetime import datetime as dt

# %%
print('current date and time:', dt.now())
# Out:
# current date and time: 2025-03-05 17:48:01.139555

# %%
print('current year:', dt.now().year)
print('current month:', dt.now().month)
print('current day:', dt.now().day)
print('current hour:', dt.now().hour)
print('current minute:', dt.now().minute)
print('current second:', dt.now().second)
# Out:
# current year: 2025
# current month: 3
# current day: 5
# current hour: 17
# current minute: 51
# current second: 49

# %%
print('current date:', dt.now().date())
print('current time:', dt.now().time())
# Out:
# current date: 2025-03-05
# current time: 17:53:54.526954

# %%
print('crrent day name:', dt.now().strftime('%A'))
print('crrent month name:', dt.now().strftime('%B'))
print('crrent day name:', dt.now().strftime('%a'))
# Out:
# crrent day name: Wednesday
# crrent month name: March
# crrent day name: Wed

# %%
import os

# %%
print('current working directory:', os.getcwd())
# Out:
# current working directory: c:\Users\sahil's pc\OneDrive\Desktop\python data science\data stuctures

# %%
files = os.listdir()
print('files in current directory:', files)
print(len(files), 'files found')
# Out:
# files in current directory: ['dictionary.ipynb', 'function.ipynb', 'libraries.ipynb', 'list.ipynb', 'PythonQuestions.ipynb']
# 5 files found

# %%
files=os.listdir(r"C:\Users\sahil's pc\OneDrive\Desktop\.vscode")
print('files in current directory:', files)
# Out:
# files in current directory: ['.git']

# %%
total_files = 0
for path, folders, files in os.walk('d:'):
    print('path - ', path)
    print('folder - ', folders)
    print('files - ', files)
    total_files += len(files)
print('total files found:', total_files)
# Out:
# path -  d:
# folder -  ['$RECYCLE.BIN', 'miniconda3', 'System Volume Information']
# files -  []
# path -  d:$RECYCLE.BIN
# folder -  ['S-1-5-21-4247236655-1861474070-354905107-1001']
# files -  []
# path -  d:$RECYCLE.BIN\S-1-5-21-4247236655-1861474070-354905107-1001
# folder -  []
# files -  ['desktop.ini']
# path -  d:miniconda3
# folder -  ['conda-meta', 'condabin', 'DLLs', 'envs', 'etc', 'include', 'Lib', 'Library', 'libs', 'Menu', 'pkgs', 'Scripts', 'share', 'shell', 'Tools']
# ...

# %%
file = r"c:path paste"
if os.path.exists(file):

# %%
file = r"paste path"
is
